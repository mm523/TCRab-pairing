# %%
import os, subprocess
import pandas as pd
import tidytcells as tt

# %%
os.chdir('../../TULIP-TCR') # assumes TULIP is installed in a separate folder

# %%
df = pd.read_csv('../TCRab-pairing/data/output/benchmarking/benchmarking_pairs.csv.gz', index_col = 0)
df = df.rename(columns = {'Epitope':'peptide', 'CDR3-a':'CDR3a', 'CDR3-b':'CDR3b', 'MHC A':'MHC'})

# %%
df['MHC'].value_counts()
# Out:
# MHC
# HLA-A*11:01        1033206
# HLA-A*02:01         651602
# HLA-B*08:01         540997
# HLA-A*01:01          83893
# HLA-A*03:01          56914
# H-2Db                16444
# HLA-B*57:01           7198
# HLA-B*07:02           6282
# H-2Kb                 4200
# HLA-A*02               623
# HLA-A*11                26
# HLA-A*02:01:48          24
# HLA-A*02:01:59           2
# HLA-A*02:01:110          2
# HLA-A*02:01:98           1
# Name: count, dtype: int64

# %%
df['MHC'] = [x.split(':')[0] for x in df['MHC']]
df['MHC'].value_counts()
# Out:
# MHC
# HLA-A*11    1033232
# HLA-A*02     652254
# HLA-B*08     540997
# HLA-A*01      83893
# HLA-A*03      56914
# H-2Db         16444
# HLA-B*57       7198
# HLA-B*07       6282
# H-2Kb          4200
# Name: count, dtype: int64

# %%
print(df.shape)
df = df[['CDR3a', 'CDR3b', 'peptide', 'MHC', 'binder']].drop_duplicates(subset=['CDR3a', 'CDR3b', 'peptide', 'MHC'], 
                                                                        keep = 'first')
print(df.shape)
assert df[['CDR3a', 'CDR3b', 'peptide', 'MHC']].value_counts().max() == 1
assert df[['CDR3a', 'CDR3b', 'peptide']].value_counts().max() == 1
df.to_csv('../TCRab-pairing/data/output/benchmarking/TULIP/benchmarking_pairs_TULIPformat.csv')
# Out:
# (2401414, 8)
# (1878223, 5)

# %%
subprocess.call("python predict.py --test_dir ../TCRab-pairing/data/output/benchmarking/TULIP/benchmarking_pairs_TULIPformat.csv --output ../TCRab-pairing/data/output/benchmarking/TULIP/".split(' '))
# Out:
# /home/marti/miniconda3/envs/TULIP/lib/python3.11/site-packages/transformers/utils/generic.py:260: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /home/marti/miniconda3/envs/TULIP/lib/python3.11/site-packages/transformers/utils/generic.py:260: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Using pad_token, but it is not set yet.
# Using sep_token, but it is not set yet.
# Using cls_token, but it is not set yet.
# Using eos_token, but it is not set yet.
# Using mask_token, but it is not set yet.
# loading hyperparameter
# Using device: cuda
# 55
# Loading models ..
# self.pad_token_id 1
# self.pad_token_id 1
# self.pad_token_id 1
# Loading the data ...
# ELAGIGILTV
# 0.5223642956700607
# Loading the data ...
# GILGFVFTL
# 0.6227361223315451
# Loading the data ...
# NLVPMVATV
# 0.6119067148952833
# Loading the data ...
# GLCTLVAML
# 0.567867124125357
# Loading the data ...
# SSLENFRAYV
# 0.5418513957307061
# Loading the data ...
# ASNENMETM
# 0.5583311872263714
# Loading the data ...
# YLQPRTFLL
# 0.577119643486791
# Loading the data ...
# LLWNGPMAV
# 0.538855799632267
# Loading the data ...
# CINGVCWTV
# 0.5120149530121316
# Loading the data ...
# KSKRTPMGF
# 0.508517254455821
# Loading the data ...
# ATDALMTGF
# 0.5545978430518707
# Loading the data ...
# AVFDRKSDAK
# 0.5117797873571858
# Loading the data ...
# IVTDFSVIK
# 0.6206774940388206
# Loading the data ...
# RAKFKQLL
# 0.554068571016264
# Loading the data ...
# RLRAEAQVK
# 0.4837201409945338
# Loading the data ...
# HGIRNASFI
# 0.6161942537267273
# Loading the data ...
# SSPPMFRV
# 0.5886342710997442
# Loading the data ...
# LSLRNPILV
# 0.5130076825503196
# Loading the data ...
# SSYRRPVGI
# 0.5511306823499278
# Loading the data ...
# LTDEMIAQY
# 0.5130233449486081
# Loading the data ...
# TTDPSFLGRY
# 0.5137001092117391
# Loading the data ...
# SPRWYFYYL
# 0.5021296228843398
# 0
